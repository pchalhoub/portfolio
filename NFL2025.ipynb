# %%
import pandas as pd

df = pd.read_csv('/content/sportsref_download.csv')
df
# Out:
#      Week      Team  TeamID  Home/Away  Opp Rslt   Pts  PtsO   Cmp   Att  ...  \
# 0       1     Colts       1          1    2    W  33.0   8.0  22.0  29.0  ...
# 1       2     Colts       1          1   20    W  29.0  28.0  23.0  34.0  ...
# 2       3     Colts       1          0   19    W  41.0  20.0  18.0  25.0  ...
# 3       4     Colts       1          0   18    L  20.0  27.0  24.0  33.0  ...
# 4       5     Colts       1          1    4    W  40.0   6.0  21.0  32.0  ...
# ..    ...       ...     ...        ...  ...  ...   ...   ...   ...   ...  ...
# 383    13    Comman      10          1   20    L  26.0  27.0  28.0  50.0  ...
# 384    13    Giants       9          0    3    L  15.0  33.0  17.0  24.0  ...
# 385    13  Patriots       3          1    9    W  33.0  15.0  24.0  31.0  ...
# 386    14   Cowboys       8          0   12  NaN  29.3  28.5  25.8  37.2  ...
# 387    14     Lions      12          1    8  NaN  29.2  22.8  22.1  31.8  ...
#
# ...

# %%
matchups_df = df.merge(
    df,
    left_on=['Week', 'TeamID', 'Opp'],
    right_on=['Week', 'Opp', 'TeamID'],
    suffixes=('', '_OPP')
)
matchups_df
# Out:
#      Week      Team  TeamID  Home/Away  Opp Rslt   Pts  PtsO   Cmp   Att  ...  \
# 0       1     Colts       1          1    2    W  33.0   8.0  22.0  29.0  ...
# 1       2     Colts       1          1   20    W  29.0  28.0  23.0  34.0  ...
# 2       3     Colts       1          0   19    W  41.0  20.0  18.0  25.0  ...
# 3       4     Colts       1          0   18    L  20.0  27.0  24.0  33.0  ...
# 4       5     Colts       1          1    4    W  40.0   6.0  21.0  32.0  ...
# ..    ...       ...     ...        ...  ...  ...   ...   ...   ...   ...  ...
# 383    13    Comman      10          1   20    L  26.0  27.0  28.0  50.0  ...
# 384    13    Giants       9          0    3    L  15.0  33.0  17.0  24.0  ...
# 385    13  Patriots       3          1    9    W  33.0  15.0  24.0  31.0  ...
# 386    14   Cowboys       8          0   12  NaN  29.3  28.5  25.8  37.2  ...
# 387    14     Lions      12          1    8  NaN  29.2  22.8  22.1  31.8  ...
#
# ...

# %%
matchups_df["Rslt"] = matchups_df["Rslt"].map({"W": 1, "L": 0})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))

sns.heatmap(matchups_df.drop(columns=['Team', 'Team_OPP', 'Rslt_OPP', 'Opp_OPP', 'Pts_OPP', 'PtsO_OPP', 'TeamID_OPP', 'Home/Away_OPP']).corr() > 0.9, annot=True, cbar=False)
plt.show()

# %%
df_train = matchups_df.drop(columns=['Team', 'Team_OPP', 'Rslt_OPP', 'Opp_OPP', 'TeamID_OPP', 'Home/Away_OPP']).copy().dropna()

# %%
df_train.columns
# Out:
# Index(['Week', 'TeamID', 'Home/Away', 'Opp', 'Rslt', 'Pts', 'PtsO', 'Cmp',
#        'Att', 'Cmp%', 'Yds', 'TD', 'Y/A', 'AY/A', 'Rate', 'Sk', 'Yds.1',
#        'Att.1', 'Yds.2', 'TD.1', 'Y/A.1', 'Ply', 'Tot', 'Y/P', 'FGA', 'FGM',
#        'XPA', 'XPM', 'Pnt', 'Yds.3', 'Pass', 'Rsh', 'Pen', '1stD', '3DConv',
#        '3DAtt', '4DConv', '4DAtt', 'Pen.1', 'Yds.4', 'FL', 'Int', 'TO',
#        'Pts_OPP', 'PtsO_OPP', 'Cmp_OPP', 'Att_OPP', 'Cmp%_OPP', 'Yds_OPP',
#        'TD_OPP', 'Y/A_OPP', 'AY/A_OPP', 'Rate_OPP', 'Sk_OPP', 'Yds.1_OPP',
#        'Att.1_OPP', 'Yds.2_OPP', 'TD.1_OPP', 'Y/A.1_OPP', 'Ply_OPP', 'Tot_OPP',
#        'Y/P_OPP', 'FGA_OPP', 'FGM_OPP', 'XPA_OPP', 'XPM_OPP', 'Pnt_OPP',
#        'Yds.3_OPP', 'Pass_OPP', 'Rsh_OPP', 'Pen_OPP', '1stD_OPP', '3DConv_OPP',
#        '3DAtt_OPP', '4DConv_OPP', '4DAtt_OPP', 'Pen.1_OPP', 'Yds.4_OPP',
#        'FL_OPP', 'Int_OPP', 'TO_OPP'],
#       dtype='object')

# %%
X = df_train[['TeamID', 'Home/Away', 'Opp', 'Pts', 'PtsO', 'Cmp',
       'Att', 'Cmp%', 'Yds', 'TD', 'Y/A', 'AY/A', 'Rate', 'Sk', 'Yds.1',
       'Att.1', 'Yds.2', 'TD.1', 'Y/A.1', 'Ply', 'Tot', 'Y/P', 'FGA', 'FGM',
       'XPA', 'XPM', 'Pnt', 'Yds.3', 'Pass', 'Rsh', 'Pen', '1stD', '3DConv',
       '3DAtt', '4DConv', '4DAtt', 'Pen.1', 'Yds.4', 'FL', 'Int', 'TO',
       'Pts_OPP', 'PtsO_OPP', 'Cmp_OPP', 'Att_OPP', 'Cmp%_OPP', 'Yds_OPP',
       'TD_OPP', 'Y/A_OPP', 'AY/A_OPP', 'Rate_OPP', 'Sk_OPP', 'Yds.1_OPP',
       'Att.1_OPP', 'Yds.2_OPP', 'TD.1_OPP', 'Y/A.1_OPP', 'Ply_OPP', 'Tot_OPP',
       'Y/P_OPP', 'FGA_OPP', 'FGM_OPP', 'XPA_OPP', 'XPM_OPP', 'Pnt_OPP',
       'Yds.3_OPP', 'Pass_OPP', 'Rsh_OPP', 'Pen_OPP', '1stD_OPP', '3DConv_OPP',
       '3DAtt_OPP', '4DConv_OPP', '4DAtt_OPP', 'Pen.1_OPP', 'Yds.4_OPP',
       'FL_OPP', 'Int_OPP', 'TO_OPP']]
y = df_train[['Rslt']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import roc_auc_score

X_train, X_test, y_train, y_test = train_test_split(X, y.values.ravel(), test_size=0.25, random_state=42)

models = [LogisticRegression(max_iter=4000), SVC(
  kernel='poly', probability=True), XGBClassifier()]

for i in range(3):
  models[i].fit(X_train, y_train)

  print(f'{models[i]} : ')
  print('Training Accuracy : ', roc_auc_score(
    y_train, models[i].predict_proba(X_train)[:,1]))
  print('Validation Accuracy : ', roc_auc_score(
    y_test, models[i].predict_proba(X_test)[:,1]))
  print()
# Out:
# LogisticRegression(max_iter=4000) :
# Training Accuracy :  1.0
# Validation Accuracy :  0.9982978723404256
#
# SVC(kernel='poly', probability=True) :
# Training Accuracy :  0.9384519589999042
# Validation Accuracy :  0.9446808510638297
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
# ...

# %% [markdown]
# XGBoost and LogisticRegression are clearly overfitting. We will still look at Logistic Regression outcomes as a frame of reference but we will rely more heavily on SVC.

# %%
subset = matchups_df.iloc[386:388]
upcoming = subset.drop(columns=[c for c in subset.columns if c not in X.columns])
upcoming
# Out:
#      TeamID  Home/Away  Opp   Pts  PtsO   Cmp   Att  Cmp%    Yds   TD  ...  \
# 386       8          0   12  29.3  28.5  25.8  37.2  69.3  271.3  2.2  ...
# 387      12          1    8  29.2  22.8  22.1  31.8  69.4  238.2  2.2  ...
#
#      1stD_OPP  3DConv_OPP  3DAtt_OPP  4DConv_OPP  4DAtt_OPP  Pen.1_OPP  \
# 386      20.0         4.8       12.5         1.1        2.1        6.2
# 387      23.3         5.3       12.1         0.8        1.5        7.8
#
#      Yds.4_OPP  FL_OPP  Int_OPP  TO_OPP
# 386       45.3     0.3      0.4     0.7
# 387       64.9     0.5      0.8     1.3
#
# [2 rows x 79 columns]

# %%
clf = LogisticRegression(max_iter=4000)
clf.fit(X_train, y_train)

print(clf.predict(upcoming))
probability = clf.predict_proba(upcoming)

i = 0

while i < len(probability):
  print(f"{upcoming.index[i]} win chance: {probability[i][1]*100}%")
  print(f"{upcoming.index[i+1]} win chance: {probability[i+1][1]*100}%")
  print("----------------------------------------")
  i += 2
# Out:
# [0. 1.]
# 386 win chance: 0.9320619111720138%
# 387 win chance: 99.80342674909865%
# ----------------------------------------

# %%
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFE

results = []

for k in range(1, X.shape[1]+1):
    rfe = RFE(estimator=LogisticRegression(max_iter=4000), n_features_to_select=k)
    X_rfe = rfe.fit_transform(X_train, y_train)
    score = cross_val_score(LogisticRegression(max_iter=4000), X_rfe, y_train, cv=5).mean()
    results.append((k, score))

results_df = pd.DataFrame(results, columns=['Num_Features', 'CV_Accuracy'])
print(results_df.sort_values('CV_Accuracy', ascending=False))
# Out:
#     Num_Features  CV_Accuracy
# 1              2     1.000000
# 2              3     1.000000
# 3              4     1.000000
# 5              6     1.000000
# 4              5     1.000000
# ..           ...          ...
# 74            75     0.982698
# 77            78     0.982698
# 76            77     0.982698
# 78            79     0.982698
# 0              1     0.764489
#
# [79 rows x 2 columns]

# %%
print(results_df.sort_values('CV_Accuracy', ascending=False).head(40))
# Out:
#     Num_Features  CV_Accuracy
# 1              2     1.000000
# 2              3     1.000000
# 3              4     1.000000
# 5              6     1.000000
# 4              5     1.000000
# 6              7     1.000000
# 7              8     1.000000
# 11            12     1.000000
# 8              9     1.000000
# 9             10     1.000000
# 10            11     1.000000
# 13            14     1.000000
# 12            13     1.000000
# 14            15     1.000000
# 15            16     1.000000
# 31            32     1.000000
# 16            17     1.000000
# 17            18     1.000000
# 18            19     1.000000
# 19            20     1.000000
# 20            21     1.000000
# 21            22     1.000000
# 22            23     1.000000
# 23            24     1.000000
# 24            25     1.000000
# 25            26     1.000000
# 26            27     1.000000
# 27            28     1.000000
# 28            29     1.000000
# 29            30     1.000000
# ...

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': LogisticRegression(max_iter=4000).fit(X_train, y_train).coef_[0]
}).sort_values(by='Coefficient', key=abs, ascending=False)

print(coef_df.head(35))
# Out:
#        Feature  Coefficient
# 3          Pts     0.866918
# 42    PtsO_OPP     0.866918
# 4         PtsO    -0.799415
# 41     Pts_OPP    -0.799415
# 78      TO_OPP     0.278252
# 30         Pen    -0.229599
# 61     FGM_OPP    -0.225984
# 23         FGM     0.221737
# 28        Pass     0.212953
# 77     Int_OPP     0.199515
# 68     Pen_OPP     0.199173
# 5          Cmp    -0.195369
# 33       3DAtt    -0.154596
# 66    Pass_OPP    -0.142606
# 74   Pen.1_OPP     0.141986
# 62     XPA_OPP     0.139987
# 34      4DConv    -0.138404
# 22         FGA     0.131950
# 60     FGA_OPP    -0.123346
# 45    Cmp%_OPP     0.120014
# 36       Pen.1    -0.115623
# 19         Ply     0.113713
# 31        1stD    -0.111759
# 72  4DConv_OPP     0.111741
# 73   4DAtt_OPP     0.103908
# 29         Rsh    -0.095113
# 47      TD_OPP     0.091851
# 76      FL_OPP     0.078737
# 57     Ply_OPP    -0.077762
# 2          Opp    -0.076199
# 71   3DAtt_OPP     0.072662
# 32      3DConv    -0.072166
# ...

# %%
X_verify = df_train[['Opp', 'Pts', 'PtsO', 'Cmp',
       'Ply', 'FGA', 'FGM',
       'Pass', 'Rsh', 'Pen', '1stD', '3DConv',
       '3DAtt', '4DConv', 'Pen.1',
       'Pts_OPP', 'PtsO_OPP', 'Cmp%_OPP',
       'TD_OPP', 'AY/A_OPP', 'Y/A.1_OPP', 'Ply_OPP',
       'Y/P_OPP', 'FGA_OPP', 'FGM_OPP', 'XPA_OPP', 'Pass_OPP', 'Pen_OPP',
       '3DAtt_OPP', '4DConv_OPP', '4DAtt_OPP', 'Pen.1_OPP',
       'FL_OPP', 'Int_OPP', 'TO_OPP']]

X_train, X_test, y_train, y_test = train_test_split(X_verify, y.values.ravel(), test_size=0.25, random_state=42)

clf = LogisticRegression(max_iter=4000)
clf.fit(X_train, y_train)

print('Training Accuracy : ', roc_auc_score(
    y_train, clf.predict_proba(X_train)[:,1]))
print('Validation Accuracy : ', roc_auc_score(
    y_test, clf.predict_proba(X_test)[:,1]))
# Out:
# Training Accuracy :  1.0
# Validation Accuracy :  1.0

# %%
subset = matchups_df.iloc[386:388]
upcoming = subset.drop(columns=[c for c in subset.columns if c not in X_verify.columns])
upcoming
# Out:
#      Opp   Pts  PtsO   Cmp   Ply  FGA  FGM  Pass  Rsh  Pen  ...  XPA_OPP  \
# 386   12  29.3  28.5  25.8  64.8  2.0  1.8  13.8  6.5  2.9  ...      3.5
# 387    8  29.2  22.8  22.1  61.6  1.7  1.3  12.4  6.8  0.8  ...      3.2
#
#      Pass_OPP  Pen_OPP  3DAtt_OPP  4DConv_OPP  4DAtt_OPP  Pen.1_OPP  FL_OPP  \
# 386      12.4      0.8       12.5         1.1        2.1        6.2     0.3
# 387      13.8      2.9       12.1         0.8        1.5        7.8     0.5
#
#      Int_OPP  TO_OPP
# 386      0.4     0.7
# 387      0.8     1.3
#
# [2 rows x 35 columns]

# %%
print(clf.predict(upcoming))
probability = clf.predict_proba(upcoming)

i = 0

while i < len(probability):
  print(f"{upcoming.index[i]} win chance: {probability[i][1]*100}%")
  print(f"{upcoming.index[i+1]} win chance: {probability[i+1][1]*100}%")
  print("----------------------------------------")
  i += 2
# Out:
# [0. 1.]
# 386 win chance: 0.44376870557051185%
# 387 win chance: 99.81135317047382%
# ----------------------------------------

# %%
subset = matchups_df.iloc[386:388]
upcoming = subset.drop(columns=[c for c in subset.columns if c not in X.columns])
upcoming
# Out:
#      TeamID  Home/Away  Opp   Pts  PtsO   Cmp   Att  Cmp%    Yds   TD  ...  \
# 386       8          0   12  29.3  28.5  25.8  37.2  69.3  271.3  2.2  ...
# 387      12          1    8  29.2  22.8  22.1  31.8  69.4  238.2  2.2  ...
#
#      1stD_OPP  3DConv_OPP  3DAtt_OPP  4DConv_OPP  4DAtt_OPP  Pen.1_OPP  \
# 386      20.0         4.8       12.5         1.1        2.1        6.2
# 387      23.3         5.3       12.1         0.8        1.5        7.8
#
#      Yds.4_OPP  FL_OPP  Int_OPP  TO_OPP
# 386       45.3     0.3      0.4     0.7
# 387       64.9     0.5      0.8     1.3
#
# [2 rows x 79 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y.values.ravel(), test_size=0.25, random_state=42)

clf = SVC(
  kernel='poly', probability=True)
clf.fit(X_train, y_train)

print(clf.predict(upcoming))
probability = clf.predict_proba(upcoming)

i = 0

while i < len(probability):
  print(f"{upcoming.index[i]} win chance: {probability[i][1]*100}%")
  print(f"{upcoming.index[i+1]} win chance: {probability[i+1][1]*100}%")
  print("----------------------------------------")
  i += 2
# Out:
# [0. 1.]
# 386 win chance: 36.55961264700563%
# 387 win chance: 66.7987513239248%
# ----------------------------------------

# %% [markdown]
# This is the most plausible

# %%
X_train, X_test, y_train, y_test = train_test_split(X_verify, y.values.ravel(), test_size=0.25, random_state=42)

clf = SVC(
  kernel='poly', probability=True)
clf.fit(X_train, y_train)

print('Training Accuracy : ', roc_auc_score(
    y_train, clf.predict_proba(X_train)[:,1]))
print('Validation Accuracy : ', roc_auc_score(
    y_test, clf.predict_proba(X_test)[:,1]))
# Out:
# Training Accuracy :  1.0
# Validation Accuracy :  1.0

# %%
subset = matchups_df.iloc[386:388]
upcoming = subset.drop(columns=[c for c in subset.columns if c not in X_verify.columns])
upcoming
# Out:
#      Opp   Pts  PtsO   Cmp   Ply  FGA  FGM  Pass  Rsh  Pen  ...  XPA_OPP  \
# 386   12  29.3  28.5  25.8  64.8  2.0  1.8  13.8  6.5  2.9  ...      3.5
# 387    8  29.2  22.8  22.1  61.6  1.7  1.3  12.4  6.8  0.8  ...      3.2
#
#      Pass_OPP  Pen_OPP  3DAtt_OPP  4DConv_OPP  4DAtt_OPP  Pen.1_OPP  FL_OPP  \
# 386      12.4      0.8       12.5         1.1        2.1        6.2     0.3
# 387      13.8      2.9       12.1         0.8        1.5        7.8     0.5
#
#      Int_OPP  TO_OPP
# 386      0.4     0.7
# 387      0.8     1.3
#
# [2 rows x 35 columns]

# %%
print(clf.predict(upcoming))
probability = clf.predict_proba(upcoming)

i = 0

while i < len(probability):
  print(f"{upcoming.index[i]} win chance: {probability[i][1]*100}%")
  print(f"{upcoming.index[i+1]} win chance: {probability[i+1][1]*100}%")
  print("----------------------------------------")
  i += 2
# Out:
# [0. 1.]
# 386 win chance: 4.9007738143770085%
# 387 win chance: 95.34048145746478%
# ----------------------------------------

# %% [markdown]
# Matchups are duplicated to confirm each other, fiable predictions are those with reasonable matchups (i.e. one team > 50%, opposing team <50%)
